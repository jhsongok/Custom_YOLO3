# %%
# 내 구글 드라이브에 연동
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Training 준비를 위한 file generation.py 파일 복사
# !cp '/content/gdrive/MyDrive/Custom_YOLO3/files_generation.py' .

# %%
# file generation for training
# !python files_generation.py
# Out:
# [classes.names] is created
# [custom_data.data] is created
# [train.txt] is created
# [test.txt] is created

# %%
# Custom Yolo training 을 위한 파일 복사
# !cp -r custom '/content/gdrive/MyDrive/Custom_YOLO3'

# %%
# Yolo3 cfg 파일 이동
# !mv '/content/gdrive/MyDrive/Custom_YOLO3/custom-train-yolo3.cfg' '/content/gdrive/MyDrive/Custom_YOLO3/custom/'
# !mv '/content/gdrive/MyDrive/Custom_YOLO3/custom-test-yolo3.cfg' '/content/gdrive/MyDrive/Custom_YOLO3/custom/'
